# %% [markdown]
# ### 1. Import dependencies

# %%
import os
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Gender <Male, Female>
#
# 		Gender_male, Gender_female
# male    1             0
# female  0             1
#
# Assume Gender is ordinal
# male => 1
# female => 0

# %% [markdown]
# Gender => Nominal
# Geography => Nominal
# CreditScore => ordinal

# %%
df = pd.read_csv("../week--02/data/processed/CEHHbInToW_binning_handled_values.csv")
df.head(10)
# Out:
#   Geography  Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    France  Female  42.00       2       0.00              1          1
# 1     Spain  Female  41.00       1   83807.86              1          0
# 2    France  Female  42.00       8  159660.80              3          1
# 3    France  Female  38.91       1       0.00              2          0
# 4     Spain  Female  43.00       2  125510.82              1          1
# 5     Spain    Male  44.00       8  113755.78              2          1
# 6    France    Male  50.00       7       0.00              2          1
# 7   Germany  Female  29.00       4  115046.74              4          1
# 8    France    Male  44.00       4  142051.07              2          0
# 9    France    Male  27.00       2  134603.88              1          1
#
#    IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# 0               1        101348.88       1            fair
# 1               1        112542.58       0            fair
# 2               0        113931.57       1            poor
# 3               0         93826.63       0            good
# 4               1         79084.10       0       excellent
# 5               0        149756.71       1            fair
# 6               1         10062.80       0       excellent
# 7               0        119346.88       1            poor
# 8               1         74940.50       0            poor
# 9               1         71725.73       0            good

# %% [markdown]
# ### 3. Encode Ordinal Variables

# %%
credit_score_dummies = pd.get_dummies(df["CreditScoreBins"], prefix="CreditScore")
credit_score_dummies
# Out:
#       CreditScore_excellent  CreditScore_fair  CreditScore_good  \
# 0                     False              True             False
# 1                     False              True             False
# 2                     False             False             False
# 3                     False             False              True
# 4                      True             False             False
# ...                     ...               ...               ...
# 9995                  False             False             False
# 9996                  False             False             False
# 9997                  False             False              True
# 9998                  False             False             False
# 9999                  False             False             False
#
#       CreditScore_poor  CreditScore_very good
# 0                False                  False
# 1                False                  False
# 2                 True                  False
# 3                False                  False
# 4                False                  False
# ...                ...                    ...
# 9995             False                   True
# 9996              True                  False
# 9997             False                  False
# 9998             False                   True
# 9999             False                   True
#
# [10000 rows x 5 columns]

# %%
encode_dict_creditScore = { "poor": 0, "fair": 1, "good": 2, "very good": 3, "excellent": 4 }

df_encoded["CreditScoreBins"] = df_encoded["CreditScoreBins"].map(encode_dict_creditScore)
df_encoded.head(10)
# Out:
#   Geography    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    France  42.00       2       0.00              1          1
# 1     Spain  41.00       1   83807.86              1          0
# 2    France  42.00       8  159660.80              3          1
# 3    France  38.91       1       0.00              2          0
# 4     Spain  43.00       2  125510.82              1          1
# 5     Spain  44.00       8  113755.78              2          1
# 6    France  50.00       7       0.00              2          1
# 7   Germany  29.00       4  115046.74              4          1
# 8    France  44.00       4  142051.07              2          0
# 9    France  27.00       2  134603.88              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  CreditScoreBins  Gender_Female  \
# 0               1        101348.88       1              NaN           True
# 1               1        112542.58       0              NaN           True
# 2               0        113931.57       1              NaN           True
# 3               0         93826.63       0              NaN           True
# 4               1         79084.10       0              NaN           True
# 5               0        149756.71       1              NaN          False
# 6               1         10062.80       0              NaN          False
# 7               0        119346.88       1              NaN           True
# 8               1         74940.50       0              NaN          False
# 9               1         71725.73       0              NaN          False
#
#    Gender_Male
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
# 6         True
# 7        False
# 8         True
# 9         True

# %% [markdown]
# ### 2. Encode Nominal Variables

# %%
nominal_vars = ["Geography", "Gender"]

geography_dummies = pd.get_dummies(df["Geography"], prefix="Geography")
gender_dummies = pd.get_dummies(df["Gender"], prefix="Gender")

df_encoded = pd.concat([df, geography_dummies], axis=1)
del df_encoded["Geography"]

df_encoded = pd.concat([df, gender_dummies], axis=1)
del df_encoded["Gender"]
df_encoded
# Out:
#      Geography    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0       France  42.00       2       0.00              1          1
# 1        Spain  41.00       1   83807.86              1          0
# 2       France  42.00       8  159660.80              3          1
# 3       France  38.91       1       0.00              2          0
# 4        Spain  43.00       2  125510.82              1          1
# ...        ...    ...     ...        ...            ...        ...
# 9995    France  39.00       5       0.00              2          1
# 9996    France  35.00      10   57369.61              1          1
# 9997    France  36.00       7       0.00              1          0
# 9998   Germany  42.00       3   75075.31              2          1
# 9999    France  28.00       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited CreditScoreBins  Gender_Female  \
# 0                  1        101348.88       1            fair           True
# 1                  1        112542.58       0            fair           True
# 2                  0        113931.57       1            poor           True
# 3                  0         93826.63       0            good           True
# 4                  1         79084.10       0       excellent           True
# ...              ...              ...     ...             ...            ...
# 9995               0         96270.64       0       very good          False
# 9996               1        101699.77       0            poor          False
# 9997               1         42085.58       1            good           True
# 9998               0         92888.52       1       very good          False
# 9999               0         38190.78       0       very good           True
#
#       Gender_Male
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 9995         True
# 9996         True
# 9997        False
# 9998         True
# 9999        False
#
# [10000 rows x 12 columns]
